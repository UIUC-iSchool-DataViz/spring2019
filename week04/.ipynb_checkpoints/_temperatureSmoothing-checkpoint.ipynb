# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Get daily summary data from: https://www.ncdc.noaa.gov/cdo-web/search 
df = pd.read_csv("/Users/achrist3/spring2019/week04/data/2018_ChampaignWeather.csv")

# %%
df
# Out:
#          STATION                      NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0    US1ILCP0061  CHAMPAIGN 1.5 SSE, IL US   40.0943   -88.2519      228.0
# 1    US1ILCP0061  CHAMPAIGN 1.5 SSE, IL US   40.0943   -88.2519      228.0
# 2    US1ILCP0061  CHAMPAIGN 1.5 SSE, IL US   40.0943   -88.2519      228.0
# 3    US1ILCP0061  CHAMPAIGN 1.5 SSE, IL US   40.0943   -88.2519      228.0
# 4    US1ILCP0061  CHAMPAIGN 1.5 SSE, IL US   40.0943   -88.2519      228.0
# 5    US1ILCP0061  CHAMPAIGN 1.5 SSE, IL US   40.0943   -88.2519      228.0
# 6    US1ILCP0061  CHAMPAIGN 1.5 SSE, IL US   40.0943   -88.2519      228.0
# 7    US1ILCP0061  CHAMPAIGN 1.5 SSE, IL US   40.0943   -88.2519      228.0
# 8    US1ILCP0061  CHAMPAIGN 1.5 SSE, IL US   40.0943   -88.2519      228.0
# 9    US1ILCP0061  CHAMPAIGN 1.5 SSE, IL US   40.0943   -88.2519      228.0
# 10   US1ILCP0061  CHAMPAIGN 1.5 SSE, IL US   40.0943   -88.2519      228.0
# ...

# %%
df.sort_values(by="DATE")
df["DATE"] = pd.to_datetime(df["DATE"])
plt.plot(df["DATE"], df["TMIN"])
plt.plot(df["DATE"], df["TMAX"])
