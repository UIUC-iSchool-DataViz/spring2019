# %%
#!pip install yt
import yt

# %%
ds = yt.load('/Users/jillnaiman1/data/IsolatedGalaxy/galaxy0030/galaxy0030')
# Out:
# yt : [INFO     ] 2019-03-28 18:41:42,679 Parameters: current_time              = 0.0060000200028298
# yt : [INFO     ] 2019-03-28 18:41:42,680 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-03-28 18:41:42,681 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-03-28 18:41:42,682 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-03-28 18:41:42,683 Parameters: cosmological_simulation   = 0.0

# %%
# printing info about the dataset
ds.print_stats()
# Out:
# Parsing Hierarchy : 100%|██████████| 173/173 [00:00<00:00, 9340.11it/s]
# yt : [INFO     ] 2019-03-28 18:42:13,678 Gathering a field list (this may take a moment.)
# level	# grids	       # cells	     # cells^3
# ----------------------------------------------
#   0	     1	         32768	            32
#   1	     8	         34304	            33
#   2	     8	        181888	            57
#   3	     8	        646968	            87
#   4	    15	        947856	            99
#   5	    51	        874128	            96
#   6	    18	        786328	            93
#   7	    28	        446776	            77
#   8	    36	        209400	            60
# ----------------------------------------------
#    	   173	       4160416
#
#
# t = 6.00002000e-03 = 1.39768066e+16 s = 4.42898275e+08 years
#
# Smallest Cell:
# 	Width: 1.221e-04 Mpc
# 	Width: 1.221e+02 pc
# 	Width: 2.518e+07 AU
# 	Width: 3.767e+20 cm

# %%
ds.field_list # what variables are in here?
# Out:
# [('all', 'creation_time'),
#  ('all', 'dynamical_time'),
#  ('all', 'metallicity_fraction'),
#  ('all', 'particle_index'),
#  ('all', 'particle_mass'),
#  ('all', 'particle_position_x'),
#  ('all', 'particle_position_y'),
#  ('all', 'particle_position_z'),
#  ('all', 'particle_type'),
#  ('all', 'particle_velocity_x'),
#  ('all', 'particle_velocity_y'),
#  ('all', 'particle_velocity_z'),
#  ('enzo', 'Average_creation_time'),
#  ('enzo', 'Bx'),
#  ('enzo', 'By'),
#  ('enzo', 'Bz'),
#  ('enzo', 'Cooling_Time'),
#  ('enzo', 'Dark_Matter_Density'),
#  ('enzo', 'Density'),
#  ('enzo', 'Electron_Density'),
#  ('enzo', 'Forming_Stellar_Mass_Density'),
#  ('enzo', 'Galaxy1Colour'),
#  ('enzo', 'Galaxy2Colour'),
#  ('enzo', 'HII_Density'),
#  ('enzo', 'HI_Density'),
#  ('enzo', 'HeIII_Density'),
#  ('enzo', 'HeII_Density'),
#  ('enzo', 'HeI_Density'),
#  ('enzo', 'MBHColour'),
#  ('enzo', 'Metal_Density'),
#  ('enzo', 'PhiField'),
#  ('enzo', 'Phi_pField'),
#  ('enzo', 'SFR_Density'),
#  ('enzo', 'Star_Particle_Density'),
#  ('enzo', 'Temperature'),
#  ('enzo', 'TotalEnergy'),
#  ('enzo', 'gammaHI'),
#  ('enzo', 'kphHI'),
#  ('enzo', 'kphHeI'),
#  ('enzo', 'kphHeII'),
#  ('enzo', 'x-velocity'),
#  ('enzo', 'y-velocity'),
#  ('enzo', 'z-velocity'),
#  ('io', 'creation_time'),
#  ('io', 'dynamical_time'),
#  ('io', 'metallicity_fraction'),
#  ('io', 'particle_index'),
#  ('io', 'particle_mass'),
#  ('io', 'particle_position_x'),
#  ('io', 'particle_position_y'),
#  ('io', 'particle_position_z'),
#  ('io', 'particle_type'),
#  ('io', 'particle_velocity_x'),
#  ('io', 'particle_velocity_y'),
#  ('io', 'particle_velocity_z')]

# %%
ds.domain_right_edge, ds.domain_left_edge
# Out:
# (YTArray([1., 1., 1.]) code_length, YTArray([0., 0., 0.]) code_length)

# %%
# quick plot, 1/2 through the "z"-dimension
p = ds.r[:,:,0.5].plot("density")
# Out:
# yt : [INFO     ] 2019-03-28 18:44:43,862 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-03-28 18:44:43,862 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-03-28 18:44:43,869 Making a fixed resolution buffer of (density) 800 by 800
# yt : [INFO     ] 2019-03-28 18:44:44,267 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
p.zoom(10)
# Out:
# yt : [INFO     ] 2019-03-28 18:45:37,753 Making a fixed resolution buffer of (density) 800 by 800
# yt : [INFO     ] 2019-03-28 18:45:37,761 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds.r[:].max("density"), ds.r[:].min("density")
# Out:
# (7.73426503924e-24 g/cm**3, 8.472937507539987e-32 g/cm**3)
